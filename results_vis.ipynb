# %%
data_rate1 = [0.89832,0.90116,0.90268,0.90132]
data_size1 = [4.38196,4.43996,4.45996,4.4156]
s = {1,2,4,8,16,32}
data_rate2 = [0.89804,0.9012,0.90004,0.90268,0.90168,0.9016]
data_size2 = [4.43744 ,4.45904 ,4.4214, 4.45996, 4.43832, 4.43072]
s = {1,2,4,8,16,32,64,100}
data_rate3 = [0.90156 ,0.9002 ,0.90116,0.90132 ,0.90248 ,0.90136 ,0.89844 ,0.90024]
data_size3 = [ 4.39476 ,4.432, 4.42608, 4.415, 4.46168 ,4.4348 ,4.41972, 4.42884]
# range(11)
data_rate4 = [0.902 ,0.90068 ,0.89972 ,0.90196 ,0.8988 ,0.90152 ,0.8992 ,0.90224 ,0.9016 ,0.90152,0.9008]
data_size4 = [4.43176 ,4.44996, 4.448 ,4.47336, 4.40336, 4.482, 4.40908, 4.4506, 4.4056 ,4.45036 ,4.41828]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ["THR", "APS", "SAPS(8)", "RAP(8,5)"]
data_bar = data_size1 # 用于柱形图的数据

fig, ax = plt.subplots()

# 画柱形图
ax.bar(x, data_bar, label='size', color='blue')

ax.set_title('sizes from different score functions')

ax.set_ylim(4.2, 4.6) 
# 显示图例
ax.legend()

# 显示图形
plt.show()

# %%
x = ["THR", "APS", "SAPS(8)", "RAP(8,5)"]
data_line = data_rate1  

fig, ax = plt.subplots()

# 画折线图
ax.plot(x, data_line, label='rates', color='red', marker='o')

ax.set_title('rates from different score functions')

ax.set_ylim(0.88, 0.92)  

ax.legend()

# 显示图形
plt.show()

# %%
s = ["1","2","4","8","16","32"]
data_rate2 = [0.89804,0.9012,0.90004,0.90268,0.90168,0.9016]
data_size2 = [4.43744 ,4.45904 ,4.4214, 4.45996, 4.43832, 4.43072]

data_bar = data_size2 

fig, ax = plt.subplots()

# 画柱形图
ax.bar(s, data_bar, label='weights', color='blue')

ax.set_title('SAPS using different weights')

ax.set_ylim(4.2, 4.6) 
# 显示图例
ax.legend()

# 显示图形
plt.show()

# %%
data_line = data_rate2  

fig, ax = plt.subplots()

# 画折线图
ax.plot(s,data_line, label='rates', color='red', marker='o')

ax.set_title('rates from different score functions')

ax.set_ylim(0.88, 0.92)  

ax.legend()

# 显示图形
plt.show()

# %%
s = {"1","2","4","8","16","32","64","100"}
data_rate3 = [0.90156 ,0.9002 ,0.90116,0.90132 ,0.90248 ,0.90136 ,0.89844 ,0.90024]
data_size3 = [ 4.39476 ,4.432, 4.42608, 4.415, 4.46168 ,4.4348 ,4.41972, 4.42884]
# range(11)
data_rate4 = [0.902 ,0.90068 ,0.89972 ,0.90196 ,0.8988 ,0.90152 ,0.8992 ,0.90224 ,0.9016 ,0.90152,0.9008]
data_size4 = [4.43176 ,4.44996, 4.448 ,4.47336, 4.40336, 4.482, 4.40908, 4.4506, 4.4056 ,4.45036 ,4.41828]

# %%
data_bar = data_size2 

fig, ax = plt.subplots()

# 画柱形图
ax.bar(s, data_bar, label='weights', color='blue')

ax.set_title('SAPS using different weights')

ax.set_ylim(4.2, 4.6) 
# 显示图例
ax.legend()

# 显示图形
plt.show()
